# %%
import requests
import re
from nltk.corpus import stopwords
import random
import pandas as pd
from nltk.stem import *
from nltk import word_tokenize
from nltk.stem import PorterStemmer

# %%
def get_book(url):
    book = requests.get(url).content.decode("utf-8")
    return book

# %%
def remove_punct(book):
    # Remove Punctuation using regex
    return re.sub(r'[^\w\s]','', book)

# %%
def remove_numbers(book):
    # Remove Punctuation using regex
    return re.sub('[^A-Za-z]+', ' ', book)

# %%
def remove_stopwords(book):
    pattern = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
    return pattern.sub('', book.lower())

# %%
def split_book(book):
    # Split book to 100 words
    book_words = book.split()
    n = 100
    parts = [(book_words[i*n : (i+1)*n]) for i in range((len(book_words)+ n-1)//n)]
    
    # Split book to paragraphs
    book_list = []
    for part in parts:
        book_list.append([" ".join(part)])
        
    # Select 200 random paragraphs from the book
    random_200 = random.sample(book_list, 200)
    
    return random_200

# %%
def parts_into_df(parts_list, label):
    df = pd.DataFrame(parts_list, columns=['Paragraphs'])
    # add label
    df['Label'] = label
    # add index
    df['Index'] = range(1, len(df)+1)
    
    return df

# %% [markdown]
# ### The 5 books (Adventure Genre) https://www.gutenberg.org/ebooks/bookshelf/82
# - The Three Musketeers by AlexandreDumas
#     - https://www.gutenberg.org/ebooks/1257
#     - https://www.gutenberg.org/ebooks/1257.txt.utf-8
# - Tarzan of the Apes by Edgar Rice Burroughs
#     - https://www.gutenberg.org/ebooks/78
#     - https://www.gutenberg.org/files/78/78-0.txt
# - The Thirty-Nine Steps by John Buchan
#     - https://www.gutenberg.org/ebooks/558
#     - https://www.gutenberg.org/files/558/558-0.txt
# - The Prisoner of Zenda by Anthony Hope
#     - https://www.gutenberg.org/ebooks/95
#     - https://www.gutenberg.org/files/95/95-0.txt
# - Captain Blood by Rafael Sabatini
#     - https://www.gutenberg.org/ebooks/1965
#     - https://www.gutenberg.org/files/1965/1965-0.txt

# %%
urls = ['https://www.gutenberg.org/ebooks/1257.txt.utf-8', 
 'https://www.gutenberg.org/files/78/78-0.txt', 
 'https://www.gutenberg.org/files/558/558-0.txt', 
 'https://www.gutenberg.org/files/95/95-0.txt', 
 'https://www.gutenberg.org/files/1965/1965-0.txt']

lables = ['a', 'b', 'c', 'd', 'e']

url_label = list(zip(urls, lables))
[(url, label) for url, label in url_label]
# Out:
# [('https://www.gutenberg.org/ebooks/1257.txt.utf-8', 'a'),
#  ('https://www.gutenberg.org/files/78/78-0.txt', 'b'),
#  ('https://www.gutenberg.org/files/558/558-0.txt', 'c'),
#  ('https://www.gutenberg.org/files/95/95-0.txt', 'd'),
#  ('https://www.gutenberg.org/files/1965/1965-0.txt', 'e')]

# %%
remove_numbers(remove_stopwords(remove_punct(get_book(urls[0]))))
# Out:
# 'project gutenberg ebook three musketeers alexandre dumas p re ebook use anyone anywhere united states parts world cost almost restrictions whatsoever may copy give away reuse terms project gutenberg license included ebook online wwwgutenbergorg located united states check laws country located using ebook title three musketeers author alexandre dumas p re release date march ebook recently updated september language english produced john p roberts iii roger labbe scott david gray sue asscher anita martin david muller david widger start project gutenberg ebook three musketeers three musketeers by alexandre dumas p re first volume dartagnan series contents authors preface three presents dartagnan elder antechamber de tr ville audience shoulder athos baldric porthos handkerchief aramis kings musketeers cardinals guards majesty king louis xiii interior musketeers concerning court intrigue dartagnan shows mousetrap seventeenth century plot thickens george villiers duke buckingham monsieur bonacieux man meung men robe men sword s guier keeper seals looks bell bonacieux home lover husband plan campaign journey countess de winter ballet la merlaison rendezvous pavilion porthos aramis thesis wife athos return hunting equipments dartagnan englishman english french procurators dinner soubrette mistress equipment aramis porthos treated gascon match cupid dream vengeance miladys secret without incommding athos procures equipment vision terrible vision siege la rochelle anjou wine sign red dovecot utility stovepipes conjugal scene bastion saintgervais council musketeers family affair fatality chat brother sister officer captivity first day captivity second day captivity third day captivity fourth day captivity fifth day means classical tragedy escape took place portsmouth august france carmelite convent b thune two varieties demons drop water man red cloak trial execution conclusion epilogue authors preface proved notwithstanding names ending os is heroes story honor relate readers nothing mythological short time ago making researches royal library history louis xiv stumbled chance upon memoirs dartagnan printedas works period authors could tell truth without risk residence less long bastilleat amsterdam pierre rouge title attracted took home permission guardian devoured intention enter analysis curious work shall satisfy referring readers appreciate pictures period pages therein find portraits penciled hand master although squibs may part traced upon doors barracks walls cabarets find likenesses louis xiii anne austria richelieu mazarin courtiers period less faithful history anquetil well known strikes capricious mind poet always affects mass readers admiring others doubtless admire details relate main preoccupation concerned matter one given thought dartagnan relates first visit de tr ville captain kings musketeers met antechamber three young men serving illustrious corps soliciting honor received bearing names athos porthos aramis must confess three strange names struck us immediately occurred us pseudonyms dartagnan disguised names perhaps illustrious else bearers borrowed names chosen day caprice discontent want fortune donned simple musketeers uniform moment rest till could find trace contemporary works extraordinary names strongly awakened curiosity catalogue alone books read object would fill whole chapter although might instructive would certainly afford readers little amusement suffice tell moment discouraged many fruitless investigations abandon search length found guided counsels illustrious friend paulin paris manuscript folio endorsed recollect title memoirs comte de la f re touching events passed france toward end reign king louis xiii commencement reign king louis xiv may easily imagined great joy turning manuscript last hope found twentieth page name athos twentyseventh name porthos thirtyfirst name aramis discovery completely unknown manuscript period historical science carried high degree appeared almost miraculous hastene ...

# %%
books_dict={}
books_dict={"book"+str(index+1):parts_into_df(split_book(remove_stopwords(remove_numbers(remove_punct(get_book(url))))), label= label) 
        for index,(url, label) in enumerate(url_label)}

# %%
books_dict["book4"].head(3)
# Out:
#                                           Paragraphs Label  Index
# 0  long could without risk soon door danger force...     d      1
# 1  strelsau shall caught like rats trap stay sapt...     d      2
# 2  said fritz perhaps theyll cut mine suggested n...     d      3

# %%
# concatenate all dataframe books
books_df = pd.concat([books_dict[book] for book in books_dict])

# %%
books_df.head(3)
# Out:
#                                           Paragraphs Label  Index
# 0  mme bonacieux knocked shutter three light regu...     a      1
# 1  dear dartagnan counsel give always lose seemed...     a      2
# 2  knob door noise de tr villes entrance turned r...     a      3

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 199
# Data columns (total 3 columns):
# Paragraphs    1000 non-null object
# Label         1000 non-null object
# Index         1000 non-null int32
# dtypes: int32(1), object(2)
# memory usage: 19.5+ KB

# %%
books_df.Label.unique()
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)

# %%
# save to csv file
books_df.to_csv('books_df.csv', index=False)

# %%
books_df = pd.read_csv('books_df.csv')
books_df.tail(3)
# Out:
#                                             Paragraphs Label  Index
# 997  aside imprecation stepping forward tore palmet...     e    198
# 998  increase rancour beg observe brought entirely ...     e    199
# 999  wings exclusion world less fortuitous liberty ...     e    200
